# %%
import spacy
import nltk
nlp=spacy.load('en_core_web_lg')
# Out:
# /home/sarvesh/.local/lib/python3.5/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.22) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)
# ...

# %%
from rake_nltk import Rake
import json
import sys
from textblob import TextBlob
import pytextrank
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/sarvesh/.local/lib/python3.5/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.22) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# ...

# %% [markdown]
# ### Book Input

# %%
with open('kech103.txt','r') as f:
    data = f.read()

# %%
r = Rake(max_length=3) 
r.extract_keywords_from_text(data)
r.get_ranked_phrases()
# Out:
# ['“ screening ”',
#  '“ ium ”',
#  'times get tempted',
#  'stimulated renewed interest',
#  'ib … viib',
#  'artificially produced short',
#  'g ., co',
#  'g ., al2o3',
#  'stable binary halide',
#  'next reported attempt',
#  'electronic configuration 3d14s2',
#  'electronic configuration 3d104s2',
#  'electronic configuration 1s22s2',
#  'periodic dependence upon',
#  'suggests new avenues',
#  'pitch blende –',
#  'ib – viib',
#  'ia – viia',
#  'd0 – 1ns2',
#  'principal quantum number',
#  'incrementally increasing number',
#  'azimuthal quantum number',
#  'elements vary periodically',
#  'chemically active metals',
#  'alkaline earth metals',
#  'whereas others stress',
#  'n ≡ ν',
#  'g ., c',
#  'bf4 ]-, whereas',
#  'electron cloud surrounding',
#  'john alexander newlands',
#  'communicate ideas related',
#  'every eighth element',
#  'discovering element 104',
#  'period easily combine',
#  'periodic table reflects',
#  'periodic table placing',
# ...

# %%
import re
text = "dsaydsajhkjdash X FIG 1.1"
re.sub("\(.*\)","",text)
re.sub("(^|\s)(I|(II)|(III)|(IV)|(V)|(VI)|(VII)|(VIII)|(IX)|X)($|\s)","",text,flags=re.IGNORECASE)
re.sub(r"\b(FIG)\s[0-9\.]{2,}s?\b", "",text,flags=re.IGNORECASE)
# Out:
# 'dsaydsajhkjdash X '
